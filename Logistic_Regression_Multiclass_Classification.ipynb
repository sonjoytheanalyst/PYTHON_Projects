# %% [markdown]
# ## All Library Function Has been Inputed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv(r'G:\CYBER SECURITY ALL MODULES\3rd SEMESTER\Dataset\iris.csv')

# %%
dataset
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
len(dataset)
# Out:
# 150

# %%
dataset['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
dataset['variety'].replace({'Setosa':'1', 'Versicolor':'2', 'Virginica':'3'},inplace=True)

# %%
dataset
# Out:
#      sepal.length  sepal.width  petal.length  petal.width variety
# 0             5.1          3.5           1.4          0.2       1
# 1             4.9          3.0           1.4          0.2       1
# 2             4.7          3.2           1.3          0.2       1
# 3             4.6          3.1           1.5          0.2       1
# 4             5.0          3.6           1.4          0.2       1
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       3
# 146           6.3          2.5           5.0          1.9       3
# 147           6.5          3.0           5.2          2.0       3
# 148           6.2          3.4           5.4          2.3       3
# 149           5.9          3.0           5.1          1.8       3
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(dataset[['sepal.length','sepal.width','petal.length','petal.width']],dataset['variety'],test_size=0.2)

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
len(y_train)
# Out:
# 120

# %%
len(y_test)
# Out:
# 30

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\jupyter\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['3', '3', '1', '2', '2', '2', '3', '1', '1', '1', '2', '2', '2',
#        '1', '3', '1', '3', '1', '3', '3', '1', '3', '3', '3', '1', '1',
#        '1', '3', '3', '1'], dtype=object)

# %%
x_test      #'Setosa':'1', 'Versicolor':'2', 'Virginica':'3'
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 120           6.9          3.2           5.7          2.3
# 144           6.7          3.3           5.7          2.5
# 5             5.4          3.9           1.7          0.4
# 63            6.1          2.9           4.7          1.4
# 99            5.7          2.8           4.1          1.3
# 93            5.0          2.3           3.3          1.0
# 101           5.8          2.7           5.1          1.9
# 14            5.8          4.0           1.2          0.2
# 31            5.4          3.4           1.5          0.4
# 0             5.1          3.5           1.4          0.2
# 62            6.0          2.2           4.0          1.0
# 68            6.2          2.2           4.5          1.5
# 97            6.2          2.9           4.3          1.3
# 48            5.3          3.7           1.5          0.2
# 121           5.6          2.8           4.9          2.0
# ...

# %% [markdown]
# ## Accuracy Test Score

# %%
lr.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ## VIsualization of Data with different species

# %%
sns.pairplot(dataset[['sepal.length','sepal.width','petal.length','petal.width','variety']],hue='variety')
