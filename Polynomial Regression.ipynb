# %% [markdown]
# ## All Library Function Has been Inputed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## The sample dataset has been uploaded using pandas library and This is a dummy data

# %%
data= pd.read_csv(r'G:\CYBER SECURITY ALL MODULES\3rd SEMESTER\polynomial_dataset.csv')

# %%
data
# Out:
#           position  Level   Salary
# 0          Manager      1    45000
# 1     Data Analyst      2    50000
# 2  Business Anlyst      3    60000
# 3               IT      4    70000
# 4       Supervisor      5   110000
# 5          Partner      6   200000
# 6               Md      7   300000
# 7         Director      8  1000000

# %% [markdown]
# ## In this dataset Level is independent data and salary is dependent data

# %% [markdown]
# ## Here I have used iloc for finding the vales of Level

# %%
x= data.iloc[:,1:2].values

# %%
x
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6],
#        [7],
#        [8]], dtype=int64)

# %%
y=data.iloc[:,2].values

# %%
y
# Out:
# array([  45000,   50000,   60000,   70000,  110000,  200000,  300000,
#        1000000], dtype=int64)

# %%
plt.scatter(x,y)

# %%
sns.lmplot(x='Level',y='Salary',data=data)

# %% [markdown]
# ## For showing linear model we have used the linear model from sklearn library

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Here i have used liner regression instead of polynomial as a result the output is correct as the model is deteced it should be nearly 269781.52056276 but its showing 429255.95238095.

# %%
reg.predict([[6.5]])
# Out:
# array([429255.95238095])

# %% [markdown]
# ## Thats why we have used polynomial regression model and we can see output is accured.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=3)

# %%
x_poly=poly.fit_transform(x)

# %%
reg2=linear_model.LinearRegression()

# %%
reg2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
reg2.predict(poly.fit_transform([[6.5]]))
# Out:
# array([269781.52056276])
